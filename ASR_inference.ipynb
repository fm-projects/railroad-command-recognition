# %%
from vosk import Model, KaldiRecognizer
import wave
import json

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from evaluate import load
from scipy.io import wavfile
import noisereduce as nr
from tqdm import tqdm

# %%
from sklearn.metrics import f1_score

# %%
from vosk import SetLogLevel
SetLogLevel(-2)

# %%
np.random.seed(0)

# %%
model = Model(lang="ru-RU", model_path="vosk-model-small-ru-0.22")

# %%
luga = pd.read_json("rzd/ESC_DATASET_v1.2/annotation/luga.json")

# %%
luga
# Out:
#                                         audio_filepath  \
# 0                  21_11_2023/2023_11_21__09_54_58.wav
# 1                  15_11_2023/2023_11_15__11_38_51.wav
# 2                  02_11_2023/2023_11_02__10_41_09.wav
# 3                  15_11_2023/2023_11_15__11_38_41.wav
# 4                  15_11_2023/2023_11_15__09_41_25.wav
# ..                                                 ...
# 605                02_11_2023/2023_11_02__10_49_36.wav
# 606  03_07_2023/3faf9502-846e-11ee-8635-c09bf4619c0...
# 607                21_11_2023/2023_11_21__10_38_03.wav
# 608                15_11_2023/2023_11_15__09_45_41.wav
# 609  03_07_2023/3fa94428-846e-11ee-a9ba-c09bf4619c0...
#
#                                        id  \
# 0                    2023_11_21__09_54_58
# 1                    2023_11_15__11_38_51
# 2                    2023_11_02__10_41_09
# 3                    2023_11_15__11_38_41
# 4                    2023_11_15__09_41_25
# ..                                    ...
# 605                  2023_11_02__10_49_36
# 606  3faf9502-846e-11ee-8635-c09bf4619c03
# 607                  2023_11_21__10_38_03
# 608                  2023_11_15__09_45_41
# 609  3fa94428-846e-11ee-a9ba-c09bf4619c03
#
#                                         text  label  attribute
# 0                            назад с башмака     17         -1
# 1    прекратить зарядку тормозной магистрали     20         -1
# 2         осадить на двадцать восемь вагонов      4         28
# 3               зарядка тормозной магистрали      6         -1
# 4         вышел из межвагонного пространства      7         -1
# ..                                       ...    ...        ...
# 605        протянуть на восемнадцать вагонов     10         18
# 606                осадить на десять вагонов      4         10
# 607          осадить на восемнадцать вагонов      4         18
# 608                        начать осаживание      3         -1
# 609                  протянуть на два вагона     10          2
#
# [610 rows x 5 columns]

# %% [markdown]
# # Denoising

# %%
for row in tqdm(luga.iterrows()):
    path = "rzd/ESC_DATASET_v1.2/luga/" + row[1]['audio_filepath']
    rate, data = wavfile.read(path)
    reduced_noise = nr.reduce_noise(y=data, sr=rate)
    wavfile.write("denoise/luga/" + row[1]['audio_filepath'], rate, reduced_noise)
# Out:
# 610it [00:16, 37.94it/s]

# %%
import librosa
import soundfile as sf

def get_random_audio_and_remove_silence(file_path, out_path, top_db=12, safe_zone=0.25):
    audio_data, sr = librosa.load(file_path, sr=None)
    non_silent_intervals = librosa.effects.split(audio_data, top_db=top_db)
    
    safe_zone = int(sr*safe_zone)
    unique_indexes = set()
    for start, end in non_silent_intervals:
        unique_indexes.update(range(max(0, start - safe_zone), min(len(audio_data), end + safe_zone)))
    processed_audio = audio_data[list(unique_indexes)]

    sf.write(out_path, processed_audio, sr)

# %%
import numpy as np
from scipy.io import wavfile
from scipy.signal import butter, lfilter

def low_pass_filter(data, cutoff, fs, order=5):
    nyquist = 0.5 * fs
    normal_cutoff = cutoff / nyquist
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    y = lfilter(b, a, data)
    return y

def reduce_noise(input_wav, output_wav, cutoff=1700.0):
    # Read the input WAV file
    fs, data = wavfile.read(input_wav)
    
    # Apply low-pass filter
    filtered_data = low_pass_filter(data, cutoff, fs)
    
    # Write the filtered data to the output WAV file
    wavfile.write(output_wav, fs, np.int16(filtered_data))

# %%
import librosa
from scipy import signal
import soundfile as sf

# %%
for row in tqdm(luga.iterrows()):
    in_path = "rzd/ESC_DATASET_v1.2/luga/" + row[1]['audio_filepath']
    out_path = "denoise/luga/" + row[1]['audio_filepath']
    get_random_audio_and_remove_silence(in_path, out_path)
# Out:
# 610it [00:04, 126.37it/s]

# %% [markdown]
# # Classes

# %%
_label2id = {
    "отказ": 0,
    "отмена": 1,
    "подтверждение": 2,
    "начать осаживание": 3,

    "осадить на (количество) вагон": 4,
    "осадить на (количество) вагонов": 4,
    "осадить на (количество) вагона": 4,

    "продолжаем осаживание": 5,
    "зарядка тормозной магистрали": 6,
    "вышел из меж вагонного пространства": 7,
    "продолжаем роспуск": 8,
    "растянуть авто сцепки": 9,
    
    "протянуть на (количество) вагон": 10,
    "протянуть на (количество) вагонов": 10,
    "протянуть на (количество) вагона": 10,

    "от сцепка": 11,
    "назад на башмак": 12,
    "захожу в меж вагонного пространство": 13,
    "остановка": 14,
    "вперёд на башмак": 15,
    "сжать авто сцепки": 16,
    "назад с башмака": 17,
    "тише": 18,
    "вперёд с башмака": 19,
    "прекратить зарядку тормозной магистрали": 20,
    "тормозить": 21,
    "отпустить": 22,
}

# %%
labels_dict = {
    "отказ": 0,
    "отмена": 1,
    "подтверждение": 2,
    "начать осаживание": 3,
    "осадить на (количество) вагон": 4,
    "продолжаем осаживание": 5,
    "зарядка тормозной магистрали": 6,
    "вышел из межвагонного пространства": 7,
    "продолжаем роспуск": 8,
    "растянуть автосцепки": 9,
    "протянуть на (количество) вагон": 10,
    "отцепка": 11,
    "назад на башмак": 12,
    "захожу в межвагонное,пространство": 13,
    "остановка": 14,
    "вперед на башмак": 15,
    "сжать автосцепки": 16,
    "назад с башмака": 17,
    "тише": 18,
    "вперед с башмака": 19,
    "прекратить зарядку тормозной магистрали": 20,
    "тормозить": 21,
    "отпустить": 22,
}

_id2label = {
    0: "отказ",
    1: "отмена",
    2: "подтверждение",
    3: "начать осаживание",
    4: "осадить на (количество) вагон",
    5: "продолжаем осаживание",
    6: "зарядка тормозной магистрали",
    7: "вышел из межвагонного пространства",
    8: "продолжаем роспуск",
    9: "растянуть автосцепки",
    10: "протянуть на (количество) вагон",
    11: "отцепка",
    12: "назад на башмак",
    13: "захожу в межвагонное,пространство",
    14: "остановка",
    15: "вперед на башмак",
    16: "сжать автосцепки",
    17: "назад с башмака",
    18: "тише",
    19: "вперед с башмака",
    20: "прекратить зарядку тормозной магистрали",
    21: "тормозить",
    22: "отпустить",
}

# %%
numbers_dict = {
    1: "один",
    2: "два",
    3: "три",
    4: "четыре",
    5: "пять",
    6: "шесть",
    7: "семь",
    8: "восемь",
    9: "девять",
    10: "десять",
    11: "одиннадцать",
    12: "двенадцать",
    13: "тринадцать",
    14: "четырнадцать",
    15: "пятнадцать",
    16: "шестнадцать",
    17: "семнадцать",
    18: "восемнадцать",
    19: "девятнадцать",
    20: "двадцать",
    21: "двадцать один",
    22: "двадцать два",
    23: "двадцать три",
    24: "двадцать четыре",
    25: "двадцать пять",
    26: "двадцать шесть",
    27: "двадцать семь",
    28: "двадцать восемь",
    29: "двадцать девять",
    30: "тридцать",
    31: "тридцать один",
    32: "тридцать два",
    33: "тридцать три",
    34: "тридцать четыре",
    35: "тридцать пять",
    36: "тридцать шесть",
    37: "тридцать семь",
    38: "тридцать восемь",
    39: "тридцать девять",
    40: "сорок",
    41: "сорок один",
    42: "сорок два",
    43: "сорок три",
    44: "сорок четыре",
    45: "сорок пять",
    46: "сорок шесть",
    47: "сорок семь",
    48: "сорок восемь",
    49: "сорок девять",
    50: "пятьдесят",
    51: "пятьдесят один",
    52: "пятьдесят два",
    53: "пятьдесят три",
    54: "пятьдесят четыре",
    55: "пятьдесят пять",
    56: "пятьдесят шесть",
    57: "пятьдесят семь",
    58: "пятьдесят восемь",
    59: "пятьдесят девять",
    60: "шестьдесят",
    61: "шестьдесят один",
    62: "шестьдесят два",
    63: "шестьдесят три",
    64: "шестьдесят четыре",
    65: "шестьдесят пять",
    66: "шестьдесят шесть",
    67: "шестьдесят семь",
    68: "шестьдесят восемь",
    69: "шестьдесят девять",
    70: "семьдесят",
    71: "семьдесят один",
    72: "семьдесят два",
    73: "семьдесят три",
    74: "семьдесят четыре",
    75: "семьдесят пять",
    76: "семьдесят шесть",
    77: "семьдесят семь",
    78: "семьдесят восемь",
    79: "семьдесят девять",
    80: "восемьдесят",
    81: "восемьдесят один",
    82: "восемьдесят два",
    83: "восемьдесят три",
    84: "восемьдесят четыре",
    85: "восемьдесят пять",
    86: "восемьдесят шесть",
    87: "восемьдесят семь",
    88: "восемьдесят восемь",
    89: "восемьдесят девять",
    90: "девяносто",
    91: "девяносто один",
    92: "девяносто два",
    93: "девяносто три",
    94: "девяносто четыре",
    95: "девяносто пять",
    96: "девяносто шесть",
    97: "девяносто семь",
    98: "девяносто восемь",
    99: "девяносто девять",
    100: "сто"
}

# %%
classes = f'{list(_label2id.keys()) + list(numbers_dict.values()) + ["[unk]"]}'
classes = classes.replace("'", '"')

# %% [markdown]
# # Vosk valid on luga

# %%
number_dict = {
    "один": 1,
    "два": 2,
    "три": 3,
    "четыре": 4,
    "пять": 5,
    "шесть": 6,
    "семь": 7,
    "восемь": 8,
    "девять": 9,
    "десять": 10,
    "одиннадцать": 11,
    "двенадцать": 12,
    "тринадцать": 13,
    "четырнадцать": 14,
    "пятнадцать": 15,
    "шестнадцать": 16,
    "семнадцать": 17,
    "восемнадцать": 18,
    "девятнадцать": 19,
    "двадцать": 20,
    "тридцать": 30,
    "сорок": 40,
    "пятьдесят": 50,
    "шестьдесят": 60,
    "семьдесят": 70,
    "восемьдесят": 80,
    "девяноста": 90,
    "сто": 100
}

number_list = list(number_dict.keys())

def extract_number(label: list[str]):
    res_list = []
    res_num = 0
    for word in label:
        if word in number_list:
            res_num += number_dict[word]
            res_list.append(word)
    if res_num == 0:
        res_num = -1
    return (res_num, ' '.join(res_list))

def get_vagon_form(n: int) -> str:
    if n % 10 == 1 and n % 100 != 11:
        return "вагон"
    elif 2 <= n % 10 <= 4 and not (12 <= n % 100 <= 14):
        return "вагона"
    else:
        return "вагонов"

vagon_dict = {i: get_vagon_form(i) for i in range(1, 101)}

def postprocess_vagon(str_label: str) -> str:
    label = str_label.split()
    voice_num, voice_str = extract_number(label)
    vagon_form = get_vagon_form(voice_num)

    if label[0] in ['осадить', 'протянуть']:
        label = [label[0]] + ["на"] + [voice_str] + [vagon_form]
    else:
        label = ["на"] + [voice_str] + [vagon_form]

    return ' '.join(label)
# Out:
# ['один', 'два', 'три', 'четыре', 'пять', 'шесть', 'семь', 'восемь', 'девять', 'десять', 'одиннадцать', 'двенадцать', 'тринадцать', 'четырнадцать', 'пятнадцать', 'шестнадцать', 'семнадцать', 'восемнадцать', 'девятнадцать', 'двадцать', 'тридцать', 'сорок', 'пятьдесят', 'шестьдесят', 'семьдесят', 'восемьдесят', 'девяноста', 'сто']

# %%
extract_number("восемьдесят")
# Out:
# (165, 'восемьдесят семьдесят восемь семь')

# %%
from nltk.stem.snowball import SnowballStemmer

correct_id2label = {
    0: "отказ",
    1: "отмена",
    2: "подтверждение",
    3: "начать осаживание",
    4: "осадить на (количество) вагон",
    5: "продолжаем осаживание",
    6: "зарядка тормозной магистрали",
    7: "вышел из межвагонного пространства",
    8: "продолжаем роспуск",
    9: "растянуть автосцепки",
    10: "протянуть на (количество) вагон",
    11: "отцепка",
    12: "назад на башмак",
    13: "захожу в межвагонное пространство",
    14: "остановка",
    15: "вперед на башмак",
    16: "сжать автосцепки",
    17: "назад с башмака",
    18: "тише",
    19: "вперед с башмака",
    20: "прекратить зарядку тормозной магистрали",
    21: "тормозить",
    22: "отпустить",
}

_id2label = {
    "отказ": 0,
    "отмена": 1,
    "подтверждение": 2,
    "начать осаживание": 3,
    "осадить на вагон": 4,
    "продолжаем осаживание": 5,
    "зарядка тормозной магистрали": 6,
    "вышел из меж вагонного пространства": 7,
    "продолжаем роспуск": 8,
    "растянуть авто сцепки": 9,
    "протянуть на вагон": 10,
    "от сцепка": 11,
    "назад на башмак": 12,
    "захожу в меж вагонного пространство": 13,
    "остановка": 14,
    "вперёд на башмак": 15,
    "сжать авто сцепки": 16,
    "назад с башмака": 17,
    "тише": 18,
    "вперёд с башмака": 19,
    "прекратить зарядку тормозной магистрали": 20,
    "тормозить": 21,
    "отпустить": 22,
}
_id2label = dict((v, k) for k, v in _id2label.items())

stemmer = SnowballStemmer("russian") 

filtered_labels = [list(filter(lambda x: x != "(количество)", 
                        _id2label[i].split()))
                    for i in range(23)]
stemmed_labels = [{stemmer.stem(word) for word in label}
                  for label in filtered_labels]

def find_nearest_label(sent: str, stemmed_labels: list[str]) -> tp.Tuple[int, str]:
    processed_sent = {stemmer.stem(word) for word in sent.split()}
    intersects = [len(processed_sent.intersection(label)) for label in stemmed_labels]
    max_common_id = np.argmax(intersects)
    return max_common_id, correct_id2label[max_common_id]

# %%
def vosk_asr(path, classes):
    wf = wave.open(path, 'rb')
    rec = KaldiRecognizer(model, wf.getframerate(), classes)
    res = ""
    partial_res = ""
    final_res = ""

    while True:
        data = wf.readframes(10000)
        if len(data) == 0:
            break
        if rec.AcceptWaveform(data):
            res += list(json.loads(rec.Result()).values())[0] + " "
        else:
            partial_res += str(json.loads(rec.PartialResult()))

    final_res = list(json.loads(rec.FinalResult()).values())[0]
    return res, partial_res, final_res

# %%
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.metrics.pairwise import cosine_similarity

# def find_nearest_label(predicted_speech: str, labels: dict) -> str:
#     vectorizer = TfidfVectorizer()
#     tfidf_matrix = vectorizer.fit_transform([predicted_speech] + list(labels.keys()))
#     cosine_similarities = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:])
#     most_similar_index = np.argmax(cosine_similarities)

#     return labels[list(labels.keys())[most_similar_index]]

# %%
import resource

peak_ram = resource.getrusage(resource.RUSAGE_SELF).ru_maxrss / 1024 / 1024
print(f'Peak RAM usage: {peak_ram} MB')
# Out:
# Peak RAM usage: 772.71875 MB

# %%
preds = []
targets = []
labels = []
pred_targets = []

for row in luga.iterrows():
    path = "rzd/ESC_DATASET_v1.2/luga/" + row[1]['audio_filepath']
    res, partial_res, final_res = vosk_asr(path, classes)
    if res == "":
        res = final_res

    targets += [row[1]['text']]
    labels += [row[1]['label']]
    pred_targets += [find_nearest_label(res, stemmed_labels)[0]]

    if find_nearest_label(res, stemmed_labels)[0] in [4, 10]:
        preds += [postprocess_vagon(res)]
    else:
        preds += [find_nearest_label(res, stemmed_labels)[1]]
    if preds[-1] != targets[-1]:
        print("clear: ", res)
        print("fix:   ", preds[-1], pred_targets[-1], extract_number(preds[-1])[0])
        print("target:", targets[-1])
        print()
# Out:
# clear:  зарядку тормозной магистрали
# fix:    зарядка тормозной магистрали 6 -1
# target: прекратить зарядку тормозной магистрали
#
# clear:  осадить на вагонов
# fix:    осадить на  вагонов 4 -1
# target: осадить на двадцать шесть вагонов
#
# clear:  двадцать четыре вагона
# fix:    на двадцать четыре вагона 4 26
# target: осадить на двадцать четыре вагона
#
# clear:  осадить на вагон
# fix:    осадить на  вагонов 4 -1
# target: осадить на один вагон
#
# clear:
# fix:    отказ 0 -1
# target: продолжаем роспуск
#
# clear:
# fix:    отказ 0 -1
# target: отцепка
#
# clear:  один вагонов
# fix:    на один вагон 4 1
# target: осадить на одиннадцать вагонов
#
# clear:  башмака
# fix:    назад на башмак 12 -1
# target: вперед с башмака
#
# clear:  отказ
# fix:    отказ 0 -1
# target: отпустить
#
# clear:  осадить на вагонов
# fix:    осадить на  вагонов 4 -1
# target: осадить на двадцать семь вагонов
#
# clear:  протянуть на вагона
# fix:    протянуть на  вагонов 10 -1
# target: протянуть на два вагона
#
# clear:  шестнадцать вагонов
# fix:    на шестнадцать вагонов 4 16
# target: осадить на шестнадцать вагонов
#
# clear:  двадцать девять вагонов
# fix:    на двадцать девять вагонов 4 31
# target: осадить на двадцать девять вагонов
#
# clear:  протянуть на
# fix:    протянуть на  вагонов 10 -1
# target: протянуть на три вагона
#
# clear:  зарядку тормозной магистрали
# fix:    зарядка тормозной магистрали 6 -1
# target: прекратить зарядку тормозной магистрали
#
# clear:  четыре
# fix:    отказ 0 -1
# target: протянуть на четырнадцать вагонов
#
# clear:  на башмак
# fix:    назад на башмак 12 -1
# target: вперед на башмак
#
# clear:  протянуть на башмак
# fix:    протянуть на  вагонов 10 -1
# target: протянуть на три вагона
#
# clear:  осадить на вагонов
# fix:    осадить на  вагонов 4 -1
# target: осадить на шесть вагонов
#
# clear:  на башмак
# fix:    назад на башмак 12 -1
# target: вперед на башмак
#
# clear:  осадить на вагонов
# fix:    осадить на  вагонов 4 -1
# target: осадить на двадцать восемь вагонов
#
# clear:  протянуть на два пятьдесят вагонов
# fix:    протянуть на пятьдесят два вагона 10 57
# target: протянуть на двадцать шесть вагонов
#
# clear:  продолжаем осадить
# fix:    на  вагонов 4 -1
# target: продолжаем осаживание
#
# clear:  протянуть на вагонов
# fix:    протянуть на  вагонов 10 -1
# target: протянуть на пять вагонов
#
# clear:  осадить восемнадцать
# fix:    осадить на восемнадцать вагонов 4 35
# target: осадить на семнадцать вагонов
#
# clear:  протянуть на вагон
# fix:    протянуть на  вагонов 10 -1
# target: протянуть на один вагон
#
# clear:  осадить на тринадцать вагонов
# fix:    осадить на тринадцать вагонов 4 16
# target: осадить на двенадцать вагонов
#
# clear:  осадить на двадцать вагонов
# fix:    осадить на двадцать вагонов 4 22
# target: осадить на двадцать семь вагонов
#
# clear:  осадить
# fix:    осадить на  вагонов 4 -1
# target: осадить на три вагона
#
# clear:  вышел из меж вагонного пространство
# fix:    вышел из межвагонного пространства 7 -1
# target: вышел в межвагонного пространства
#
# clear:  три вагон
# fix:    на три вагона 4 3
# target: осадить на три вагона
#
# clear:  протянуть на двенадцать вагона вперёд
# fix:    протянуть на двенадцать вагонов 10 12
# target: протянуть на двенадцать вагонов вперед
#
# clear:  пространства
# fix:    вышел из межвагонного пространства 7 -1
# target: захожу в межвагонное пространство
#
# clear:
# fix:    отказ 0 -1
# target: остановка
#
# clear:  протянуть на двадцать вагонов вперёд
# fix:    протянуть на двадцать вагонов 10 22
# target: протянуть на двадцать вагонов вперед
#
# clear:  осадить на один на вагонов
# fix:    осадить на один вагон 4 1
# target: осадить на восемнадцать вагонов
#
# clear:  зарядку тормозной
# fix:    зарядка тормозной магистрали 6 -1
# target: прекратить зарядку тормозной магистрали
#
# clear:  осадить на восемьдесят вагонов
# fix:    осадить на восемьдесят вагонов 4 165
# target: осадить на восемьдесят два вагона
#
# clear:
# fix:    отказ 0 -1
# target: назад на башмак
#
# clear:  протянуть на вагонов
# fix:    протянуть на  вагонов 10 -1
# target: протянуть на двадцать восемь вагонов
#
# clear:  на двадцать пять вагонов
# fix:    на двадцать пять вагонов 4 27
# target: осадить на двадцать пять вагонов
#
# clear:  осадить на отмена
# fix:    осадить на  вагонов 4 -1
# target: осадить на двадцать вагонов
#
# clear:  зарядка тормозной магистрали
# fix:    зарядка тормозной магистрали 6 -1
# target: прекратить зарядку тормозной магистрали
#
# clear:  десять
# fix:    отказ 0 -1
# target: тише
#
# clear:  пять
# fix:    отказ 0 -1
# target: захожу в межвагонное пространство
#
# clear:  протянуть на вагонов
# fix:    протянуть на  вагонов 10 -1
# target: протянуть на восемь вагонов
#
# clear:  осадить на двадцать вагонов
# fix:    осадить на двадцать вагонов 4 22
# target: осадить на двадцать два вагона
#
# clear:
# fix:    отказ 0 -1
# target: отпустить
#
# clear:  протянуть на два
# fix:    протянуть на два вагона 10 2
# target: протянуть на двадцать шесть вагонов
#
# clear:  осадить на вагонов
# fix:    осадить на  вагонов 4 -1
# target: осадить на десять вагонов
#
# clear:
# fix:    отказ 0 -1
# target: продолжаем роспуск
#
# clear:
# fix:    отказ 0 -1
# target: подтверждение
#
# clear:  осадить на вагонов
# fix:    осадить на  вагонов 4 -1
# target: осадить на двадцать восемь вагонов
#
# clear:
# fix:    отказ 0 -1
# target: отмена
#
# clear:  башмак
# fix:    назад на башмак 12 -1
# target: вперед на башмак
#
# clear:
# fix:    отказ 0 -1
# target: тише
#
# clear:
# fix:    отказ 0 -1
# target: протянуть на тринадцать вагонов
#
# clear:
# fix:    отказ 0 -1
# target: сжать автосцепки
#
# clear:  в меж вагонного пространство
# fix:    захожу в межвагонное пространство 13 -1
# target: вышел из межвагонного пространства
#
# clear:
# fix:    отказ 0 -1
# target: осадить на двадцать вагонов
#
# clear:  осадить на семь вагон
# fix:    осадить на семь вагонов 4 7
# target: осадить на семь вагон
#
# clear:  осадить на вагон
# fix:    осадить на  вагонов 4 -1
# target: осадить на два вагона
#
# clear:  продолжаем осадить
# fix:    на  вагонов 4 -1
# target: продолжаем осаживание
#
# clear:  протянуть на вагон
# fix:    протянуть на  вагонов 10 -1
# target: протянуть на пятнадцать вагонов
#
# clear:  осадить на вагонов
# fix:    осадить на  вагонов 4 -1
# target: осадить на четырнадцать вагонов
#
# clear:  два
# fix:    отказ 0 -1
# target: отпустить
#
# clear:
# fix:    отказ 0 -1
# target: подтверждение
#
# clear:  протянуть на вагонов
# fix:    протянуть на  вагонов 10 -1
# target: протянуть на девять вагонов
#
# clear:  башмак
# fix:    назад на башмак 12 -1
# target: вперед на башмак
#
# clear:  на башмак
# fix:    назад на башмак 12 -1
# target: вперед на башмак
#
# clear:  назад башмака
# fix:    назад на башмак 12 -1
# target: назад с башмака
#
# clear:  осадить на восемь шесть вагонов
# fix:    осадить на восемь шесть вагонов 4 21
# target: осадить на восемьдесят шесть вагонов
#
# clear:  осадить на два на
# fix:    осадить на два вагона 4 2
# target: осадить на двадцать шесть вагонов
#
# clear:  вагонов
# fix:    на  вагонов 4 -1
# target: осадить на двадцать один вагонов
#
# clear:  протянуть на вагона
# fix:    протянуть на  вагонов 10 -1
# target: протянуть на пять вагонов
#
# clear:
# fix:    отказ 0 -1
# target: протянуть на три вагона
#
# clear:
# fix:    отказ 0 -1
# target: назад с башмака
#
# clear:  башмак
# fix:    назад на башмак 12 -1
# target: вперед на башмак
#
# clear:  протянуть на вагона
# fix:    протянуть на  вагонов 10 -1
# target: протянуть на четыре вагона
#
# clear:
# fix:    отказ 0 -1
# target: протянуть на восемнадцать вагонов
#
# clear:
# fix:    отказ 0 -1
# target: продолжаем осаживание
#
# clear:  протянуть на вагона
# fix:    протянуть на  вагонов 10 -1
# target: протянуть на два вагона
#
# clear:  осадить на вагона
# fix:    осадить на  вагонов 4 -1
# target: осадить на двадцать восемь вагонов
#
# clear:  протянуть на вагон
# fix:    протянуть на  вагонов 10 -1
# target: протянуть на пятнадцать вагонов
#
# clear:  протянуть на вагона
# fix:    протянуть на  вагонов 10 -1
# target: протянуть на два вагона
#
# clear:  два шесть вагон
# fix:    на шесть два вагонов 4 8
# target: протянуть на двадцать шесть вагонов
#
# clear:  осадить на вагон
# fix:    осадить на  вагонов 4 -1
# target: осадить на двадцать восемь вагонов
#
# clear:  десять
# fix:    отказ 0 -1
# target: тише
#
# clear:  осадить на двадцать вагонов
# fix:    осадить на двадцать вагонов 4 22
# target: осадить на двадцать семь вагонов
#
# clear:
# fix:    отказ 0 -1
# target: отпустить

# %%
import resource

peak_ram = resource.getrusage(resource.RUSAGE_SELF).ru_maxrss / 1024 / 1024
print(f'Peak RAM usage: {peak_ram} MB')
# Out:
# Peak RAM usage: 772.71875 MB

# %%
for i in preds:
    print(i)
    print(postprocess_vagon(i))
    break
# Out:
# назад с башмака
# назад  вагонов

# %%
post_processing_preds = []
for i in preds:
    post_processing_preds += [find_nearest_label(i, labels_dict)]

# %%
f1_score(labels, post_processing_preds, average='weighted')
# Out:
# 0.8207299322517616

# %%
wer = load("wer")

# %%
wer_score = wer.compute(predictions=preds, references=targets)
wer_score
# Out:
# 0.08337622233659289

# %% [markdown]
# # Whisper valid on luga

# %%
import whisper

# %%
model_name="base"
lang="ru"

options = whisper.DecodingOptions(language=lang, without_timestamps=True, fp16 = False)
model = whisper.load_model(model_name)
tokenizer = whisper.tokenizer.get_tokenizer(True, language="ru", task=options.task)

# %%
import resource

peak_ram = resource.getrusage(resource.RUSAGE_SELF).ru_maxrss / 1024 / 1024
print(f'Peak RAM usage: {peak_ram} MB')
# Out:
# Peak RAM usage: 984.484375 MB

# %%
preds = []
targets = []
for row in luga.iterrows():
    path = "rzd/ESC_DATASET_v1.2/luga/" + row[1]['audio_filepath']

    audio = whisper.load_audio(path)
    audio = whisper.pad_or_trim(audio)
    mel = whisper.log_mel_spectrogram(audio)

    res = model.decode( mel, options).text

    preds += [res]
    targets += [row[1]['text']]
    print(res)
    print(row[1]['text'])
    print()
# Out:
# Назад в ашмаке
# назад с башмака
#
# Репротив зарядки, тормозной магистралы.
# прекратить зарядку тормозной магистрали
#
# Ассалит на 28 гонах
# осадить на двадцать восемь вагонов
#
# Зарядка тормозной магистрали
# зарядка тормозной магистрали
#
# Вышел из них в угу на запресс-транса.
# вышел из межвагонного пространства
#
# Ротянуть на 16-й вагонах
# протянуть на шестнадцать вагонов
#
# Вышел и шмешуагонного пространства.
# вышел из межвагонного пространства
#
# Вперед на пасмах!
# вперед на башмак
#
# Посадить на 8 вагонах.
# осадить на восемь вагонов
#
# осадить на 4 вагона
# осадить на четыре вагона
#
# Осадить на 26 гонах.
# осадить на двадцать шесть вагонов
#
# Перез башмака
# вперед с башмака
#
# Астановка!
# остановка
#
# Протянуть на 8 вагонов.
# протянуть на восемь вагонов
#
# Протянуть мне 4 гонки.
# протянуть на четыре вагона
#
# Ротинут на 17 логинах.
# протянуть на семнадцать вагонов
#
# Останавливка!
# остановка
#
# Отсюда
# отцепка
#
# Посадить на три вагона.
# осадить на три вагона
#
# Протенуть на сеймбой грановле.
# протянуть на семь вагонов
#
# Протянуть на 16 вобонов
# протянуть на шестнадцать вагонов
#
# Открас!
# отказ
#
# Верябто, терминозный вно-рустрал.
# зарядка тормозной магистрали
#
# 24 огона
# осадить на двадцать четыре вагона
#
# Вышел измежлагонного пространства.
# вышел из межвагонного пространства
#
# И рецепт-мака
# вперед с башмака
#
# А раз-тону ты в тасцетке!
# растянуть автосцепки
#
# Оставить на один в облен
# осадить на один вагон
#
# Пробовься, брость!
# продолжаем роспуск
#
# Садить на один из этих вот и онов.
# осадить на одиннадцать вагонов
#
# Протянуть на 8 вагонах.
# протянуть на восемь вагонов
#
# Отсюда
# отцепка
#
# Отсыпка!
# отцепка
#
# Дыхожу, между гонной апространства.
# захожу в межвагонное пространство
#
# Посадить на 26 в обонах.
# осадить на двадцать шесть вагонов
#
# Даромазии
# тормозить
#
# Бат муяма
# отмена
#
# А садить на 19-х годов.
# осадить на девятнадцать вагонов
#
# Посадить на 9 лагонов.
# осадить на девять вагонов
#
# Отмена!
# отмена
#
# Заказин между муугольной пространства.
# захожу в межвагонное пространство
#
# Отсветка!
# отцепка
#
# Протянуть на один вагон.
# протянуть на один вагон
#
# Посадить на 12 вагонов.
# осадить на шестнадцать вагонов
#
# Посадительно. Девинат сеть вагонов.
# осадить на двенадцать вагонов
#
# Верет на башенак
# вперед на башмак
#
# Протянуть на 15 вагонов.
# протянуть на пятнадцать вагонов
#
# Осадить на два вагона.
# осадить на два вагона
#
# Захажем из вагонная пространства.
# захожу в межвагонное пространство
#
# Протянуть на 26 гонов.
# протянуть на двадцать шесть вагонов
#
# Отказ!
# отказ
#
# Посадить на 16-х годов
# осадить на шестнадцать вагонов
#
# Отсюда!
# отцепка
#
# Посадить на 7 вогонов.
# осадить на семь вагонов
#
# Осадить на 17 вагонов.
# осадить на семнадцать вагонов
#
# Прочиную на 12 лагон.
# протянуть на двенадцать вагонов
#
# Садить на 26 вагонах.
# осадить на двадцать шесть вагонов
#
# Мазер Звучники
# назад с башмака
#
# Посадить на один слоугоном.
# осадить на одиннадцать вагонов
#
# Тиша!
# тише
#
# Отказ!
# отказ
#
# Верёв, спосмыка!
# вперед с башмака
#
# Отпускать!
# отпустить
#
# Остановка
# остановка
#
# осадить на 12 вагонов
# осадить на двенадцать вагонов
#
# Протянуть на 9 вагонов.
# протянуть на девять вагонов
#
# Насадить на 20 сенную гонор.
# осадить на двадцать семь вагонов
#
# Посадить на 9 г.
# осадить на девять вагонов
#
# тормозить
# тормозить
#
# Отмена!
# отмена
#
# Отсадить на 13 влаконов.
# осадить на тринадцать вагонов
#
# начать осаживание
# начать осаживание
#
# осадить на 18 вагонах
# осадить на восемнадцать вагонов
#
# Озадить на 18-х годов.
# осадить на восемнадцать вагонов
#
# Протянуть на 6 вагонов.
# протянуть на шесть вагонов
#
# Астанобка!
# остановка
#
# Протянуть на 9 лагонов.
# протянуть на девять вагонов
#
# Вышел из Межвагонного пространства.
# вышел из межвагонного пространства
#
# А сегит на 12 вгонов.
# осадить на двенадцать вагонов
#
# Ротянуть над водой надо.
# протянуть на два вагона
#
# Протянуть на 7 вагонов.
# протянуть на семь вагонов
#
# Оходить на всех нас и к лагонам.
# осадить на шестнадцать вагонов
#
# Посадить на 7 вогонов.
# осадить на семь вагонов
#
# Заходим в угонное пространство.
# захожу в межвагонное пространство
#
# Попустим!
# отпустить
#
# осадить на 86 вагон
# осадить на восемьдесят шесть вагонов
#
# Скорее сбошка.
# вперед с башмака
#
# Торнозить!
# тормозить
#
# Посадить на 18 года.
# осадить на восемнадцать вагонов
#
# Вышел из межвагонного пространства.
# вышел из межвагонного пространства
#
# Посадительно 9 лагонов.
# осадить на девять вагонов
#
# Прочинуть на 27 гонов.
# протянуть на двадцать семь вагонов
#
# Вышел измеж мгонного пространства.
# вышел из межвагонного пространства
#
# Назад с башмотан
# назад с башмака
#
# Перед на басмак
# вперед на башмак
#
# Протянуть на 14 вагонов.
# протянуть на четырнадцать вагонов
#
# Жай тебя в тостерке!
# сжать автосцепки
#
# осадить на один вагон
# осадить на один вагон
#
# Тормозить!
# тормозить
#
# А садить на 20 дней трогона.
# осадить на двадцать девять вагонов
#
# Вперёд с башмака
# вперед с башмака
#
# осадить на 8 вагонов
# осадить на восемь вагонов
#
# Перед набошмак
# вперед на башмак
#
# Продолжаем массаж вне.
# продолжаем осаживание
#
# Назад на башмак
# назад на башмак
#
# тормозить
# тормозить
#
# Сперёд с башмоков
# вперед с башмака
#
# Посадить на 10 вагонов.
# осадить на десять вагонов
#
# Осадить на 4 вагона.
# осадить на четыре вагона
#
# Посадительно 11 вагонов
# осадить на одиннадцать вагонов
#
# Сладием на 15 вагонах.
# осадить на пятнадцать вагонов
#
# Прокимут на 16 лобонов
# протянуть на шестнадцать вагонов
#
# Посадить на 17 вагонов
# осадить на семнадцать вагонов
#
# Открас.
# отказ
#
# Отмена
# отмена
#
# Протемнительно приятного гона!
# протянуть на три вагона
#
# Пропротив зарядку перемотного гестрая.
# прекратить зарядку тормозной магистрали
#
# осадительно 5 вагонов
# осадить на пять вагонов
#
# Посадить на 16 вагонов.
# осадить на шестнадцать вагонов
#
# Протянуть на 10 вагонов.
# протянуть на десять вагонов
#
# осадить на 4 вагона
# осадить на четыре вагона
#
# 14 лаббров.
# протянуть на четырнадцать вагонов
#
# Отказ!
# отказ
#
# А садить на сигнал в трагонах.
# осадить на семнадцать вагонов
#
# Вышел из Межвагонного пространства.
# вышел из межвагонного пространства
#
# Начать осаживание.
# начать осаживание
#
# Зарядка тормозной магистрали.
# зарядка тормозной магистрали
#
# Протянуть на 6 гонов.
# протянуть на шесть вагонов
#
# Закожем междунаю пространство.
# захожу в межвагонное пространство
#
# Протянуть на 13 влогонов.
# протянуть на тринадцать вагонов
#
# Отсёдь!
# отцепка
#
# Перед на башмах
# вперед на башмак
#
# Расстоимость of the circuit
# растянуть автосцепки
#
# Протянуть на 8 вагонах.
# протянуть на восемь вагонов
#
# Ракемнит на 6 вагонов
# протянуть на шесть вагонов
#
# Посадить на 10 вагонов.
# осадить на десять вагонов
#
# Вот эти мутные три в обонах.
# протянуть на три вагона
#
# Перед на башмаг.
# вперед на башмак
#
# Ротюнуть на 27 гонов.
# протянуть на двадцать семь вагонов
#
# Отмена!
# отмена
#
# осадить на два вагона
# осадить на два вагона
#
# Прикратил в порядку, которым мы с дымы кестрали.
# прекратить зарядку тормозной магистрали
#
# А все дико шестло донев.
# осадить на шесть вагонов
#
# Растянуть его в тасцепке.
# растянуть автосцепки
#
# Бэпппургдюня
# подтверждение
#
# Продолжаем осаживать.
# продолжаем осаживание
#
# Террия на башмот.
# вперед на башмак
#
# Назад на письмах
# назад на башмак
#
# А сидит на 32 символбона.
# осадить на двадцать восемь вагонов
#
# подтверждение
# подтверждение
#
# Посадить на один вагон.
# осадить на один вагон
#
# Отследить на 16 вагонов.
# осадить на шестнадцать вагонов
#
# Тормозить!
# тормозить
#
# Прочинуть на 28 вагонов.
# протянуть на двадцать восемь вагонов
#
# Посадить на 7 вагонов
# осадить на семь вагонов
#
# Тормозить
# тормозить
#
# Посадительно 7 вагонов
# осадить на семь вагонов
#
# Протянуть на 20 вагонов.
# протянуть на двадцать вагонов
#
# Начать осаживание
# начать осаживание
#
# Отмена!
# отмена
#
# Назадный башмак
# назад на башмак
#
# Посадить на 17 вагонов.
# осадить на семнадцать вагонов
#
# Отпустите.
# отпустить
#
# Оставить на 28 логонов.
# осадить на двадцать восемь вагонов
#
# Ротянуть на 26 г.
# протянуть на двадцать шесть вагонов
#
# Продолжаем осоживание.
# продолжаем осаживание
#
# Просумнуть на тротуров.
# протянуть на пять вагонов
#
# остановка
# остановка
#
# Протемнительно 18 вагонов
# протянуть на восемнадцать вагонов
#
# Отмена!
# отмена
#
# Высвел из миссблогона и пространства.
# вышел из межвагонного пространства
#
# Посадить на один вагон.
# осадить на один вагон
#
# Посадительно. 12 вагонов.
# осадить на шестнадцать вагонов
#
# Ассадитный синтез Робернов
# осадить на семнадцать вагонов
#
# Протимать на один год
# протянуть на один вагон
#
# Подтверждение
# подтверждение
#
# Отменировай!
# отмена
#
# Желтят остатки.
# сжать автосцепки
#
# Дарома здесь
# тормозить
#
# Осадить на 12 лагонов.
# осадить на двенадцать вагонов
#
# Тихо! Тихо!
# тише
#
# Жать автосцепки
# сжать автосцепки
#
# На садить на 12 гонах.
# осадить на двенадцать вагонов
#
# Садите на 27 вагонах
# осадить на двадцать семь вагонов
#
# А садить на 4 вагона.
# осадить на четыре вагона
#
# Посадительно 4 ревогона.
# осадить на четыре вагона
#
# А садить на 12 лагонов.
# осадить на двенадцать вагонов
#
# Особи, к ней при заблона.
# осадить на три вагона
#
# отпустить
# отпустить
#
# Я садить, мне длинно, а ты не вагонов?
# осадить на двенадцать вагонов
#
# При троте взородку там можно на гестрале.
# прекратить зарядку тормозной магистрали
#
# Заходу между Вагон и Апространством.
# захожу в межвагонное пространство
#
# Отмена!
# отмена
#
# Протемнентный применитель вагонов
# протянуть на тринадцать вагонов
#
# Продолжаем рост пуск
# продолжаем роспуск
#
# Протянуть на 22 гунат.
# протянуть на двадцать вагонов
#
# протянуть на 4 вагона
# протянуть на четыре вагона
#
# Посадить на 7 вагонов
# осадить на семь вагонов
#
# Протянуть на 17 вгонов.
# протянуть на семнадцать вагонов
#
# Оставить на темноции к уголосу.
# осадить на семнадцать вагонов
#
# Аказ!
# отказ
#
# Вышив измежеводной пространстве.
# вышел в межвагонного пространства
#
# Посадить на 14 вагонов
# осадить на четырнадцать вагонов
#
# Сдели как ревогона.
# осадить на три вагона
#
# Протянуть на 12 вагонов.
# протянуть на двенадцать вагонов
#
# Назад с башмоткой
# назад с башмака
#
# Радежом республики.
# продолжаем роспуск
#
# осадить на 5 вагонов
# осадить на пять вагонов
#
# Протенеть на 12 лобов на сперед.
# протянуть на двенадцать вагонов вперед
#
# Протянуть на 18 лагонов
# протянуть на восемнадцать вагонов
#
# Пермазить
# тормозить
#
# Посадить на 8 вагонах.
# осадить на восемь вагонов
#
# Захожу межгодонная пространства.
# захожу в межвагонное пространство
#
# осадить на два года
# осадить на два вагона
#
# Посадить на 8 погонов.
# осадить на восемь вагонов
#
# Начать осознанную.
# начать осаживание
#
# Останавливаем.
# остановка
#
# Отзагить на 19 вагонов.
# осадить на девятнадцать вагонов
#
# Зарядте тормозна магистрали.
# зарядка тормозной магистрали
#
# Протянуть на 20 вагонов вперед.
# протянуть на двадцать вагонов вперед
#
# Назад на кошмар.
# назад на башмак
#
# Посадить на 4 вагона.
# осадить на четыре вагона
#
# осадить на 5 гонов
# осадить на пять вагонов
#
# Вышел из Межуагонного пространства.
# вышел из межвагонного пространства
#
# Посадить на два вагона.
# осадить на два вагона
#
# Растенуть автосепки.
# растянуть автосцепки
#
# Осадить на 11 гонах.
# осадить на одиннадцать вагонов
#
# Протянуть на 16 вагонов.
# протянуть на шестнадцать вагонов
#
# Отмена!
# отмена
#
# Посадительно 10 вагонов.
# осадить на десять вагонов
#
# осадить на 10 вагонов
# осадить на десять вагонов
#
# Посадить на 8 вовгонов
# осадить на восемь вагонов
#
# Ужат в тасыпке!
# сжать автосцепки
#
# Протянуть на кривогонах.
# протянуть на три вагона
#
# Продимают на 27 гонов.
# протянуть на двадцать семь вагонов
#
# Сперед, сбошла кляну.
# вперед с башмака
#
# Афазии 1.18 вагонах
# осадить на восемнадцать вагонов
#
# Репротив зарядку тормозного кустрала.
# прекратить зарядку тормозной магистрали
#
# Назад на башмот
# назад на башмак
#
# Жать автостепки
# сжать автосцепки
#
# Протянуть на 9 погонов.
# протянуть на девять вагонов
#
# Протянуть на 11 гунов
# протянуть на одиннадцать вагонов
#
# Протемпно 27 въжунов
# протянуть на двадцать семь вагонов
#
# Оходи на 8-2 огона.
# осадить на восемьдесят два вагона
#
# Назадно, башняк!
# назад на башмак
#
# Ракинуть на 28 гонов.
# протянуть на двадцать восемь вагонов
#
# Отпустить!
# отпустить
#
# Отсюда!
# отцепка
#
# Посадить на 1 вагон
# осадить на один вагон
#
# Посадить на три вагона.
# осадить на три вагона
#
# Отказ!
# отказ
#
# Осталось бы!
# остановка
#
# Посадить на два вагона.
# осадить на два вагона
#
# Музыка с макарей
# назад с башмака
#
# Посадительно 3 вагона.
# осадить на три вагона
#
# Протянуть на 12 лагонов.
# протянуть на двенадцать вагонов
#
# Желкая в тасцепке
# сжать автосцепки
#
# А садить на 16 лагонов
# осадить на шестнадцать вагонов
#
# Твисы!
# тише
#
# осадить на 8 вагонов
# осадить на восемь вагонов
#
# Протянуть на 5 вагонов.
# протянуть на пять вагонов
#
# Лидно 25 вагону
# осадить на двадцать пять вагонов
#
# осадить на 22-м
# осадить на двадцать вагонов
#
# Пропротив зарядки тормозного гестраста.
# прекратить зарядку тормозной магистрали
#
# осадить на один вагон
# осадить на один вагон
#
# Пермозить
# тормозить
#
# Продолжаем рост, Буско.
# продолжаем роспуск
#
# Продолжен насаживание.
# продолжаем осаживание
#
# Зарядка тормозной магистрали.
# зарядка тормозной магистрали
#
# Отсыпка
# отцепка
#
# Ракенет на 28 вагонов
# протянуть на двадцать восемь вагонов
#
# Заходим из угонной пространства.
# захожу в межвагонное пространство
#
# осадить на 5 вагонов
# осадить на пять вагонов
#
# Протянуть на 6 ребёнок.
# протянуть на шесть вагонов
#
# осадить на четыре лагона
# осадить на четыре вагона
#
# Осадить на 15 вагонов.
# осадить на пятнадцать вагонов
#
# Заходим в Бехлагонное пространство.
# захожу в межвагонное пространство
#
# Вперед на башмак
# вперед на башмак
#
# Протемутный один в обе.
# протянуть на один вагон
#
# Отсопа!
# отцепка
#
# Осадить на 10 вагонов.
# осадить на десять вагонов
#
# Остановка!
# остановка
#
# Пермозить!
# тормозить
#
# Прикратить зерядку там изменили гестраю.
# прекратить зарядку тормозной магистрали
#
# Протинуть на 27 гонов.
# протянуть на двадцать семь вагонов
#
# Кисер!
# тише
#
# Астоновка
# остановка
#
# Протянуть на 12 вагонов.
# протянуть на шестнадцать вагонов
#
# Рассказуем на трёхбуре трёхбуре трёхбуре.
# захожу в межвагонное пространство
#
# Посадить на 4 вагона
# осадить на четыре вагона
#
# Подверждение
# подтверждение
#
# Осадить на 17 вагонов.
# осадить на семнадцать вагонов
#
# Отказ!
# отказ
#
# Нечете сожживание
# начать осаживание
#
# Посадить на 10 вагонов.
# осадить на десять вагонов
#
# Протянуть мы восемь на донес.
# протянуть на восемь вагонов
#
# Вышив измеж в огромного пространства.
# вышел из межвагонного пространства
#
# осадить на 3 вагона
# осадить на три вагона
#
# Протянуть на 7 вогонов.
# протянуть на семь вагонов
#
# Афадикно-20 в Агона
# осадить на двадцать два вагона
#
# Протелить на 10 лабанов.
# протянуть на десять вагонов
#
# Осадить на 4 вагона.
# осадить на четыре вагона
#
# Протянуть на 12 вагонов.
# протянуть на двенадцать вагонов
#
# Маленький страд!
# отпустить
#
# протянуть на 10 вагонов
# протянуть на десять вагонов
#
# Протянуть на 26 лобонок
# протянуть на двадцать шесть вагонов
#
# Осадить на 27 гонов.
# осадить на двадцать семь вагонов
#
# Отказ!
# отказ
#
# Садить на 10 влажных.
# осадить на десять вагонов
#
# Перед спецмака
# вперед с башмака
#
# вперед на башмак
# вперед на башмак
#
# начать осаживать
# начать осаживание
#
# Начать осаживание
# начать осаживание
#
# Раболзом Роско
# продолжаем роспуск
#
# осадить на 7 вагонов
# осадить на семь вагонов
#
# Берет на башмак
# вперед на башмак
#
# Протянуть на 5 вагонов.
# протянуть на пять вагонов
#
# Высвел из наклогона ва прострасту.
# вышел из межвагонного пространства
#
# Продолжаем роскошку.
# продолжаем роспуск
#
# Посадить на 10 вагонов.
# осадить на десять вагонов
#
# осадить на шесть вагонов
# осадить на шесть вагонов
#
# Тормозить
# тормозить
#
# Продолжаем рост.
# продолжаем роспуск
#
# Боттвы, что здесь?
# подтверждение
#
# осадить на четыре лагона
# осадить на четыре вагона
#
# Астановка!
# остановка
#
# Посадить на 12 вагонов
# осадить на двенадцать вагонов
#
# Вестерновка!
# остановка
#
# Назад в основу так.
# назад с башмака
#
# Посадить на три вагона.
# осадить на три вагона
#
# Прикратить зарядку тормозной магистрали.
# прекратить зарядку тормозной магистрали
#
# Отсоупка!
# отцепка
#
# Остадительно, тринадцать вагонах.
# осадить на тринадцать вагонов
#
# Вперед на башмат.
# вперед на башмак
#
# Зарядка тормозной магистрали
# зарядка тормозной магистрали
#
# Вперед на Башмар.
# вперед на башмак
#
# Оставить на 22 гонок.
# осадить на двадцать вагонов
#
# Продолжаем ров спуск.
# продолжаем роспуск
#
# Посадить на 13 вакуанов.
# осадить на тринадцать вагонов
#
# Продолжаем усаживание.
# продолжаем осаживание
#
# осадить на 28 гонок
# осадить на двадцать восемь вагонов
#
# Отмена!
# отмена
#
# До свидетелей 5 года.
# осадить на пять вагонов
#
# Протянуть на 18 лагонов.
# протянуть на восемнадцать вагонов
#
# Оставить на 8 вагонах.
# осадить на восемь вагонов
#
# Подтверждение.
# подтверждение
#
# Осадить на 12 обонов.
# осадить на двенадцать вагонов
#
# Назад на башмак
# назад на башмак
#
# остановка
# остановка
#
# протянуть на 10 вагонов
# протянуть на десять вагонов
#
# Вперед на баснов
# вперед на башмак
#
# Осадительно 13 вагонах.
# осадить на тринадцать вагонов
#
# осадить на 10 вагонов
# осадить на десять вагонов
#
# Несо!
# тише
#
# Открас!
# отказ
#
# Допс-мена!
# отмена
#
# Отсоха!
# отцепка
#
# Осадить на 12 лагонов.
# осадить на двенадцать вагонов
#
# Протянуть на два вагона.
# протянуть на два вагона
#
# Отумиума!
# отмена
#
# Перед збашем окна
# вперед с башмака
#
# Восемь измельчаемая пространства.
# вышел из межвагонного пространства
#
# Тормозить!
# тормозить
#
# Продолжаем массаживание.
# продолжаем осаживание
#
# Отмена.
# отмена
#
# Протолепно тронадцать раз.
# протянуть на тринадцать вагонов
#
# Дотверждение!
# подтверждение
#
# Протянуть на 17 вагонов.
# протянуть на семнадцать вагонов
#
# Посадить на пять вагонов
# осадить на пять вагонов
#
# Протянуть на 4 вагона.
# протянуть на четыре вагона
#
# Прекратим зарядку от тормозного гипстрали.
# прекратить зарядку тормозной магистрали
#
# Протянуть на 7 вагонов.
# протянуть на семь вагонов
#
# Ростынуть автесеки
# растянуть автосцепки
#
# Отказ!
# отказ
#
# Рочинуть на 27 годов.
# протянуть на двадцать семь вагонов
#
# Посадительно два вагона.
# осадить на два вагона
#
# Тарбазик!
# тормозить
#
# Животевка с окей
# сжать автосцепки
#
# Посадительно 19-два глав.
# осадить на девятнадцать вагонов
#
# Сзарьянтерто Магестро, Леонид.
# зарядка тормозной магистрали
#
# Протянуть на два вагона.
# протянуть на два вагона
#
# Протянуть на три вагона.
# протянуть на три вагона
#
# Астануфта!
# остановка
#
# Беретесь на смока.
# вперед с башмака
#
# Отмена!
# отмена
#
# осадить на 8-1 вагон
# осадить на восемьдесят один вагон
#
# Назад сбошнока.
# назад с башмака
#
# Остадить на 8-5 вагонов.
# осадить на восемьдесят пять вагонов
#
# осадить на 12 вагонов
# осадить на двенадцать вагонов
#
# Чушай!
# тише
#
# Назад на ваш мак.
# назад на башмак
#
# Зафазуемую глубонную пространству.
# захожу в межвагонное пространство
#
# Вперёд спешмотан
# вперед с башмака
#
# Восло из мест вагонного пространства.
# вышел из межвагонного пространства
#
# А садить на 20 раз.
# осадить на двадцать вагонов
#
# Астоновка
# остановка
#
# Ну чайте сожживание!
# начать осаживание
#
# Вперед, спосмотка!
# вперед с башмака
#
# Прекратить зарядку там из намагистрали.
# прекратить зарядку тормозной магистрали
#
# Прикратить зарядку тормозной магистрали.
# прекратить зарядку тормозной магистрали
#
# осадить на 13 вагонов
# осадить на тринадцать вагонов
#
# Астанозка
# остановка
#
# Прокимит мы 13 лабонов
# протянуть на тринадцать вагонов
#
# Назадбас Макар!
# назад с башмака
#
# видео с бестного
# вперед с башмака
#
# Настом, Настом!
# остановка
#
# Садите на 11 вагонов.
# осадить на одиннадцать вагонов
#
# Посадить на 14 погонов.
# осадить на четырнадцать вагонов
#
# Посадительно. Четыре вагона.
# осадить на четыре вагона
#
# начать с зоне
# начать осаживание
#
# Садитесь всем вагонах!
# осадить на семь вагон
#
# Задить на зологороду.
# осадить на два вагона
#
# Посадить на два вагона.
# осадить на два вагона
#
# Выши измежлагом на пространстве.
# вышел из межвагонного пространства
#
# Сурет на башмот.
# вперед на башмак
#
# Назад сбошла
# назад с башмака
#
# Остадить на 84 вагону.
# осадить на восемьдесят четыре вагона
#
# Ротинут на 17 вагонов.
# протянуть на семнадцать вагонов
#
# Продолжаем осаживание.
# продолжаем осаживание
#
# Протянуть на 15 вагонах.
# протянуть на пятнадцать вагонов
#
# Посадить на 7 вагонов.
# осадить на семь вагонов
#
# Посадить на 20 вагон.
# осадить на двадцать вагонов
#
# Назадно башнад!
# назад на башмак
#
# Ветяной 15 огона
# протянуть на пятнадцать вагонов
#
# Особенно три вагона.
# осадить на три вагона
#
# Астомовка
# остановка
#
# Посадить на 15 вагонов.
# осадить на пятнадцать вагонов
#
# осадить на 6 вагонов
# осадить на шесть вагонов
#
# Садит на 27 гонах.
# осадить на двадцать семь вагонов
#
# Осадить на 18 вагонах.
# осадить на восемнадцать вагонов
#
# Кисо!
# тише
#
# Посадить на 9 вагонов
# осадить на девять вагонов
#
# Посадить на 14 вагонах.
# осадить на четырнадцать вагонов
#
# Отсыпка!
# отцепка
#
# Перед на Босмар.
# вперед на башмак
#
# Отпустить!
# отпустить
#
# Абкас!
# отказ
#
# А садить на 10-3 г.
# осадить на девять вагонов
#
# Отсевка!
# отцепка
#
# Посадительно 6 вагонов.
# осадить на шесть вагонов
#
# А садить на 8 вонах
# осадить на восемь вагонов
#
# Остановка!
# остановка
#
# Жатер в тасцепте
# сжать автосцепки
#
# Бабь мне, а не
# отмена
#
# Назад вошмотка
# назад с башмака
#
# оследить на 15 вагонах
# осадить на пятнадцать вагонов
#
# Протянуть на 9 лагонов.
# протянуть на девять вагонов
#
# Противнуть на 16 вагонов.
# протянуть на шестнадцать вагонов
#
# Заходим из вагонного пространства.
# захожу в межвагонное пространство
#
# Захожу на жуговное пространство.
# захожу в межвагонное пространство
#
# Посадить на 11 вагонов.
# осадить на одиннадцать вагонов
#
# Осадить на 19 вагонов.
# осадить на девятнадцать вагонов
#
# Пап, твердение!
# подтверждение
#
# Посадить на 6 вагонов.
# осадить на шесть вагонов
#
# Ракемот на 14 лагонов
# протянуть на четырнадцать вагонов
#
# Протянуть на 5 вагонов.
# протянуть на пять вагонов
#
# Назад на башмаг.
# назад на башмак
#
# Назад сбошнока.
# назад с башмака
#
# Отсыпка.
# отцепка
#
# Астоновка
# остановка
#
# Протянуть на 19-й проглонов.
# протянуть на девятнадцать вагонов
#
# отпустить
# отпустить
#
# осадить на 802 лагона
# осадить на восемьдесят два вагона
#
# Отцеп!
# отцепка
#
# Откуда?
# отпустить
#
# Подвердение!
# подтверждение
#
# Отсадить на 4 мосить в гонах.
# осадить на четырнадцать вагонов
#
# Додалжай массаж.
# продолжаем осаживание
#
# Протянуть на 16 вагонов.
# протянуть на шестнадцать вагонов
#
# осадить на 27 вагонов
# осадить на двадцать семь вагонов
#
# осадить на 28 вагонов
# осадить на двадцать восемь вагонов
#
# Осадить на 26 гонок.
# осадить на двадцать шесть вагонов
#
# Продолжаем осозвучить
# продолжаем осаживание
#
# Ротянуть надевать лаганов.
# протянуть на девять вагонов
#
# А садить на 12 лагон.
# осадить на двенадцать вагонов
#
# Берет на басмот.
# вперед на башмак
#
# осадить на 18 вагонов
# осадить на восемнадцать вагонов
#
# При каратии зарядку тормозуем на гестраве.
# прекратить зарядку тормозной магистрали
#
# Протянуть на 6 вагонов.
# протянуть на шесть вагонов
#
# Остадить на 10 вагонов.
# осадить на десять вагонов
#
# Брат, ты не отмышай себе, Буанов.
# протянуть на шесть вагонов
#
# Теши!
# тише
#
# Протянуть на 26 гонов.
# протянуть на двадцать шесть вагонов
#
# Начать осаживание
# начать осаживание
#
# Припратите ли оттуда моё магистрали.
# прекратить зарядку тормозной магистрали
#
# Назад на башенак
# назад на башмак
#
# Отмена.
# отмена
#
# Верят на космон.
# вперед на башмак
#
# Протемпля тревогон
# протянуть на три вагона
#
# Жать автосыпки
# сжать автосцепки
#
# осадить на 9 вагонов
# осадить на девять вагонов
#
# Остануевка
# остановка
#
# Назад в башмаках.
# назад с башмака
#
# Прекратить зарядку тормозной ноги страли.
# прекратить зарядку тормозной магистрали
#
# осадить на 86 года
# осадить на восемьдесят шесть вагонов
#
# Верёвка по шмакам.
# вперед с башмака
#
# Отсыпка!
# отцепка
#
# Посадить на 26 вагонов.
# осадить на двадцать шесть вагонов
#
# растянуть астасепки
# растянуть автосцепки
#
# Осадить на 15 вагонах.
# осадить на пятнадцать вагонов
#
# Протянуть на 10 вагонов.
# протянуть на десять вагонов
#
# Сиди и трва-тс один вагом.
# осадить на двадцать один вагонов
#
# Протюнет на 11 лобенов.
# протянуть на одиннадцать вагонов
#
# начать осаживание
# начать осаживание
#
# Потянуть на 5-2 года.
# протянуть на пять вагонов
#
# осадить на два вагона
# осадить на два вагона
#
# Осадить на 20 вагонов
# осадить на двадцать вагонов
#
# Назад сбоснука
# назад с башмака
#
# Протянуть на 13 вагонах.
# протянуть на тринадцать вагонов
#
# Протянуть на 19 лагонов.
# протянуть на девятнадцать вагонов
#
# Перед збашмака
# вперед с башмака
#
# Посадительно 15 в год
# осадить на пятнадцать вагонов
#
# Осадить на 28 вагонов.
# осадить на двадцать восемь вагонов
#
# Зато жемный жёгон мой пристранство!
# захожу в межвагонное пространство
#
# Проклинуть на трогогонах.
# протянуть на три вагона
#
# Остануовка.
# остановка
#
# осадить на два вагона
# осадить на два вагона
#
# Тиша
# тише
#
# Ротинает на 15 лагон.
# протянуть на пятнадцать вагонов
#
# Сперед на башмак
# вперед на башмак
#
# назад на башмаг
# назад на башмак
#
# Назадство слотото
# назад с башмака
#
# осадить на 7 вагонов
# осадить на семь вагонов
#
# Протянуть на четыре левогона.
# протянуть на четыре вагона
#
# Вышел из Межвагонного пространства.
# вышел из межвагонного пространства
#
# Вышел из Межевогонного пространства.
# вышел из межвагонного пространства
#
# тормозить
# тормозить
#
# Назад на башмот.
# назад на башмак
#
# Вперед, пропасть мог!
# вперед на башмак
#
# осадить на 12 гонов
# осадить на двенадцать вагонов
#
# В роте Мутнин четыре года.
# протянуть на четыре вагона
#
# Высвязнение вагонного пространства.
# вышел из межвагонного пространства
#
# Протинеть на 18 годов
# протянуть на восемнадцать вагонов
#
# Афинодиат остепки
# растянуть автосцепки
#
# Остадить на 26 гонов.
# осадить на двадцать шесть вагонов
#
# Ротинут на 28 гонов.
# протянуть на двадцать восемь вагонов
#
# Здравствуйте, а вы сцепки.
# растянуть автосцепки
#
# Должаем ассаживание.
# продолжаем осаживание
#
# Перед на башмак
# вперед на башмак
#
# Озадить на 8-м с 3-го года.
# осадить на восемьдесят три вагона
#
# Оставить на 25 гонах.
# осадить на двадцать пять вагонов
#
# тормозить
# тормозить
#
# Осадить на 15 вагонов
# осадить на пятнадцать вагонов
#
# Ротянуть на 8 погланов.
# протянуть на восемь вагонов
#
# Вышел из Межуагонного пространства.
# вышел из межвагонного пространства
#
# протянуть на один вагон
# протянуть на один вагон
#
# Вперед на бошмак
# вперед на башмак
#
# В роте нахожу
# протянуть на два вагона
#
# Постановка
# остановка
#
# Посадить на 17 вагонов.
# осадить на семнадцать вагонов
#
# Протенеть на 16 вагонах.
# протянуть на шестнадцать вагонов
#
# Ротинутный 28 вагонов
# протянуть на двадцать восемь вагонов
#
# Посадительно 3 вагона.
# осадить на три вагона
#
# Посадить на 17 кг.
# осадить на семнадцать вагонов
#
# осадить на 16 лагонов
# осадить на шестнадцать вагонов
#
# Протемуть на 5 уголов.
# протянуть на пять вагонов
#
# Осадить на 19-х годов.
# осадить на девятнадцать вагонов
#
# Татурждение
# подтверждение
#
# Дарма зить!
# тормозить
#
# Отказ!
# отказ
#
# назад на башмак
# назад на башмак
#
# Посадить на 308.
# осадить на двадцать восемь вагонов
#
# осадить на 9 лагонов
# осадить на девять вагонов
#
# Посадить на 19 вагонов.
# осадить на двенадцать вагонов
#
# Жетевто с сыпки!
# сжать автосцепки
#
# тормози
# тормозить
#
# Протюнет на 27 гонах.
# протянуть на двадцать семь вагонов
#
# Протянуйте на свободу.
# протянуть на пятнадцать вагонов
#
# Посадить на 6 вагонов
# осадить на шесть вагонов
#
# Астанута!
# остановка
#
# Вышел из Межгогонного пространства.
# вышел из межвагонного пространства
#
# Вышел изменивали в бонус на пространстве.
# вышел из межвагонного пространства
#
# Протянуть на 18 вагонах.
# протянуть на восемнадцать вагонов
#
# Прочем мы бувы обонны.
# протянуть на два вагона
#
# Разум 23 свободно
# протянуть на двадцать шесть вагонов
#
# Посадить на 19-х годов
# осадить на девятнадцать вагонов
#
# Я седикно вверх с умер, да?
# осадить на двадцать восемь вагонов
#
# Тише, сын!
# тише
#
# А садить на 20 сель в обонах
# осадить на двадцать семь вагонов
#
# осадить на 17 вагонов
# осадить на семнадцать вагонов
#
# Жать это автосцепки.
# сжать автосцепки
#
# Отказ!
# отказ
#
# Отпустите!
# отпустить
#
# Подтверждение
# подтверждение
#
# Здесь
# тише
#
# Протянуть на 9 вагонов.
# протянуть на девять вагонов
#
# ЖЕНТЫ в тесылке!
# сжать автосцепки
#
# Назад на башмак
# назад на башмак
#
# Назад на башмак
# назад на башмак
#
# Заказуемую сглубь на пространстве.
# захожу в межвагонное пространство
#
# Маткозкнов!
# отпустить
#
# осадить на 3 вагона
# осадить на три вагона
#
# Отсыпка!
# отцепка
#
# Отказ!
# отказ
#
# Открас!
# отказ
#
# осадить на 8-9 уголов
# осадить на восемьдесят девять вагонов
#
# Протимедный 12 лагонов
# протянуть на двенадцать вагонов
#
# Посадительно 8 вагонах.
# осадить на восемь вагонов
#
# Мастерновка!
# остановка
#
# Протянуть на 9 вагонов.
# протянуть на девять вагонов
#
# Посадить на 16 вагонов
# осадить на шестнадцать вагонов
#
# Раскинуть автесепки.
# растянуть автосцепки
#
# Прочемить на 19 обойнов.
# протянуть на девятнадцать вагонов
#
# Передна басмата
# вперед на башмак
#
# Заходим из Вагонной пространство.
# захожу в межвагонное пространство
#
# Проксинует 18 вагонах.
# протянуть на восемнадцать вагонов
#
# Афлодительно 10 вогонов.
# осадить на десять вагонов
#
# Посадить на 18-м гоноп.
# осадить на восемнадцать вагонов
#
# Начайте сожжирание
# начать осаживание
#
# Протянуть на два вагона.
# протянуть на два вагона

# %%
import resource

peak_ram = resource.getrusage(resource.RUSAGE_SELF).ru_maxrss / 1024 / 1024
print(f'Peak RAM usage: {peak_ram} MB')
# Out:
# Peak RAM usage: 1061.59375 MB

# %%
wer_score = wer.compute(predictions=preds, references=targets)
wer_score
# Out:
# 0.8008234688625836
